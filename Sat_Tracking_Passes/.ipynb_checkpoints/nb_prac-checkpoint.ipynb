# %% [markdown]
# ## Imports

# %% [markdown]
# Packages

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Data

# %%
df = pd.read_csv('Ionosphere Data _ Final Exam.csv')
df = df.iloc[:,0:5]
# Out:
#     Altitude\n[km]  Electron Density\n[m-3]  dAlt [m]     dNe [m-3]  \
# 0              100             2.270000e+10         0  0.000000e+00
# 1              150             2.800000e+10     50000  2.540000e+10
# 2              200             5.040000e+10     50000  3.920000e+10
# 3              250             1.400000e+11     50000  9.520000e+10
# 4              300             2.190000e+11     50000  1.800000e+11
# 5              350             2.010000e+11     50000  2.100000e+11
# 6              400             1.520000e+11     50000  1.770000e+11
# 7              450             1.080000e+11     50000  1.300000e+11
# 8              500             7.600000e+10     50000  9.200000e+10
# 9              550             5.450000e+10     50000  6.530000e+10
# 10             600             4.010000e+10     50000  4.730000e+10
# 11             650             3.040000e+10     50000  3.530000e+10
# 12             700             2.360000e+10     50000  2.700000e+10
# ...

# %% [markdown]
# ## Params

# %%
print("hi")
# Out:
# hi
