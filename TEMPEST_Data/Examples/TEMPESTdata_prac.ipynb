# %%
# Init
import numpy as np
import h5py
import matplotlib as plt

# %%
# Get Data
datfile = h5py.File('TEMPEST_L1_pub_20210401T235923_20210402T005535_v2.1.h5', 'r')
scan = datfile['scan']
print(list(scan))

blat = datfile['scan/blat'][:]
blon = datfile['scan/blon']
TB = datfile['scan/TB']
# scanangdat = datfile['scan/scanang']
# list(scanangdat)
# Out:
# ['SCalt', 'SClat', 'SClon', 'SCpitch', 'SCroll', 'SCyaw', 'TA', 'TB', 'UTCtime', 'asds', 'binc', 'blat', 'blon', 'landmask', 'scanang']

# %%
# plt.scatter
# Out:
# [array([-58.546387, -60.39209 , -58.194824, -60.501953, -59.64502 ,
#                nan,        nan,        nan,        nan,        nan,
#         -58.370605, -59.16162 , -59.8208  ,        nan, -58.875977,
#                nan,        nan, -59.864746, -60.018555, -60.040527,
#         -59.64502 , -60.370117, -60.21631 , -58.678223, -58.590332,
#         -59.952637, -59.49121 , -58.854004,        nan,        nan,
#         -59.776855, -60.0625  , -60.15039 , -58.128906, -58.854004,
#                nan, -58.546387, -58.788086, -59.359375, -60.128418,
#                nan, -59.40332 , -58.282715, -59.930664, -58.32666 ,
#                nan,        nan, -58.788086,        nan, -59.666992,
#                nan, -58.98584 ,        nan, -60.172363, -59.513184,
#         -58.348633, -59.293457, -59.666992, -59.88672 ,        nan,
#         -59.710938, -59.623047,        nan, -60.63379 ,        nan,
#         -58.98584 ,        nan, -59.754883, -59.666992, -58.81006 ,
# ...

# %%
#np.shape(TB[2,:,:])
np.shape(blat)
list(blat)
# Out:
# [array([ 54.74806   ,  55.277435  ,  54.793533  ,  55.505157  ,
#          55.364574  ,          nan,          nan,          nan,
#                  nan,          nan,  56.414818  ,  56.71039   ,
#          56.89367   ,          nan,  56.871555  ,          nan,
#                  nan,  57.2121    ,  57.17867   ,  56.72361   ,
#          56.139313  ,  56.08109   ,  55.65887   ,  55.060574  ,
#          54.718277  ,  54.133415  ,  53.773582  ,  51.622368  ,
#                  nan,          nan,  50.541836  ,  50.473236  ,
#          50.42823   ,  49.386658  ,  49.392326  ,          nan,
#          49.120205  ,  48.45507   ,  48.277573  ,  47.99776   ,
#                  nan,  47.236534  ,  46.08879   ,  45.93629   ,
#          45.46321   ,          nan,          nan,  44.247272  ,
#                  nan,  43.239906  ,          nan,  43.026707  ,
#                  nan,  42.823704  ,  41.56916   ,  40.833805  ,
#          40.554966  ,  39.998386  ,  38.862686  ,          nan,
# ...

# %%
type(blat)
# Out:
# numpy.ndarray
